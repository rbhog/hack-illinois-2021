# %%
import numpy as np
matrix = np.array([[ 719,    9,    1,   13,    6,    1,    5,   23,  131],
       [  10,  663,    1,    4,    0,    3,   36,   19,  106],
       [   0,    1,  711,    5,   22,    0,    1,    0,   82],
       [   3,    2,    8,  620,   11,    3,    3,    2,  166],
       [   2,    0,   13,   19,  692,    1,    3,    0,  111],
       [   3,    9,    2,    2,    4,  673,   10,    6,   93],
       [   2,    2,    1,    0,    1,    2,  791,    0,   58],
       [  36,    8,    0,    4,    3,    2,   16,  601,  143],
       [  85,   36,   31,   71,   71,   40,  157,   32, 6782]])

matrix = matrix / np.sum(matrix, axis=1)
# print(np.sum(matrix, axis=1))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.heatmap(matrix, annot=True, cmap='Blues')

ax.set_title('Weed Classification Confusion Matrix\n\n')
ax.set_xlabel('\nPredicted Category (0-7 are weeds)')
ax.set_ylabel('Actual Category (0-7 are weeds)\n')

## Ticket labels - List must be in alphabetical order
# ax.xaxis.set_ticklabels([np.arange(9)].items())
# ax.yaxis.set_ticklabels([np.arange(9)].items())

## Display the visualization of the Confusion Matrix.
plt.show()
